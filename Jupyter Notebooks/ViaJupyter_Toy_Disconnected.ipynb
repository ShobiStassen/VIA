# %%
import pyVIA.core as via

# %%
via.main_Toy(ncomps=30, knn=10, random_seed=41, dataset='Toy4',
                 foldername="/home/shobi/Trajectory/Datasets/Toy4/")
# Out:
# dataset, ncomps, knn, seed Toy4 30 10 41
# /home/shobi/anaconda3/envs/ViaEnv/lib/python3.7/site-packages/anndata/_core/anndata.py:119: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# input data has shape 1000 (samples) x 30 (features)
# time is Mon Feb  1 14:33:57 2021
# commencing global pruning
# Share of edges kept after Global Pruning 50.23 %
# number of components in the original full graph 2
# for downstream visualization purposes we are also constructing a low knn-graph
# size neighbor array in low-KNN in pca-space for visualization (1000, 3)
# commencing community detection
# partition type MVP
# time is Mon Feb  1 14:33:57 2021
# 35  clusters before handling small/big
# There are 0 clusters that are too big
# Toy: global cluster graph pruning level 1
# number of components before pruning 2
# there are  2 components in the graph
# root user ['T1_M1', 'T2_M1']
# ...
